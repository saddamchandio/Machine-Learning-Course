# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('data/employee data.xlsx')
df.head()
# Out:
#           Employee       Location     Sex  Salary Date Hired  Exempt  \
# 0    Krista Orcutt   Pennsylvania  Female   54176 1991-10-22   False
# 1        Cora Soto  Massachusetts  Female   58120 1992-01-15    True
# 2     James Millen     Washington    Male   26135 1992-05-25   False
# 3  Tara Applewhite     California  Female   80274 1992-05-30    True
# 4       Devin Lear  Massachusetts    Male   43532 1992-06-29   False
#
#    Unnamed: 6  Unnamed: 7
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN

# %%
df.drop(columns=['Unnamed: 6', 'Unnamed: 7'], inplace=True)
df.head()
# Out:
#           Employee       Location     Sex  Salary Date Hired  Exempt
# 0    Krista Orcutt   Pennsylvania  Female   54176 1991-10-22   False
# 1        Cora Soto  Massachusetts  Female   58120 1992-01-15    True
# 2     James Millen     Washington    Male   26135 1992-05-25   False
# 3  Tara Applewhite     California  Female   80274 1992-05-30    True
# 4       Devin Lear  Massachusetts    Male   43532 1992-06-29   False

# %%
df['Location'].value_counts()
# Out:
# Location
# California       108
# New York          91
# Massachusetts     90
# Pennsylvania      46
# Washington        45
# Arizona           20
# Name: count, dtype: int64

# %%
gender_location_counts = df.groupby(['Location', 'Sex']).size()
gender_location_counts
# Out:
# Location       Sex
# Arizona        Female     5
#                Male      15
# California     Female    44
#                Male      64
# Massachusetts  Female    43
#                Male      47
# New York       Female    51
#                Male      40
# Pennsylvania   Female    17
#                Male      29
# Washington     Female    16
#                Male      29
# dtype: int64

# %%
num_people = df.query("Location == 'Massachusetts' and Salary > 58000").shape[0]
print(num_people)
# Out:
# 27

# %%
df.query("Location == 'Massachusetts' and (Sex=='Female' or Salary > 50000)")
# Out:
#             Employee       Location     Sex  Salary Date Hired  Exempt
# 1          Cora Soto  Massachusetts  Female   58120 1992-01-15    True
# 7        Terry Gross  Massachusetts    Male   64497 1992-09-19    True
# 17      Kimberly Vos  Massachusetts  Female   57568 1993-03-18    True
# 20     Richard Guard  Massachusetts    Male   60587 1993-05-28    True
# 28       PhyllisTodd  Massachusetts  Female   23142 1993-10-24   False
# ..               ...            ...     ...     ...        ...     ...
# 352    Joan Morrison  Massachusetts  Female   83972 2010-07-31    True
# 360       Irving Kim  Massachusetts    Male   51647 2010-12-12   False
# 367       Brian Bass  Massachusetts    Male   66145 2011-03-25    True
# 381  Filomena Jordan  Massachusetts  Female   48789 2011-12-14   False
# 397     Joseph Ramos  Massachusetts    Male   52303 2012-07-18   False
#
# [62 rows x 6 columns]

# %%
df1 = pd.read_json('data/iris.json')
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
url = "https://www.fdic.gov/bank-failures/failed-bank-list"
df2 = pd.read_html(url)

# %%
df2[0]
# Out:
#                                             Bank Name                City  \
# 0                        The Santa Anna National Bank          Santa Anna
# 1                                Pulaski Savings Bank             Chicago
# 2                  The First National Bank of Lindsay             Lindsay
# 3               Republic First Bank dba Republic Bank        Philadelphia
# 4                                       Citizens Bank            Sac City
# 5                            Heartland Tri-State Bank             Elkhart
# 6                                 First Republic Bank       San Francisco
# 7                                      Signature Bank            New York
# 8                                 Silicon Valley Bank         Santa Clara
# 9                                   Almena State Bank              Almena
# 10                         First City Bank of Florida   Fort Walton Beach
# 11                               The First State Bank       Barboursville
# ...

# %%
url = "https://www.sbp.org.pk/careers/status.asp"
tables = pd.read_html(url)
print("Number of tables found:", len(tables))
tables[12]
# Out:
# Number of tables found: 15
#         0                                                  1              2  \
# 0   S.No.                                          Positions  Advertisement
# 1       1            Banking Policy & Regulations Department     Click Here
# 2       2                   Cyber Risk Management Department     Click Here
# 3       3                          Cyber Security Department     Click Here
# 4       4          Museum, Art Gallery & Archives Department     Click Here
# 5       5                         Monetary Policy Department     Click Here
# 6       6  Contractual positions in External Communicatio...     Click Here
# 7       7               Assistant Director (OG-2) - Archives     Click Here
# 8       8                  Economic Policy Review Department     Click Here
# 9       9                                Research Department     Click Here
# 10     10                         Additional Director (OG-6)     Click Here
# ...

# %%
import sqlite3

# %%
conn = sqlite3.connect('data/chinook.db')
conn

# %%
# conn = sqlite3.connect('Chinook_Sqlite.sqlite')
# conn

# %%
tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type ='table';", conn)
# album = pd.read_sql("SELECT * FROM Album;", conn)
tables
# Out:
# Empty DataFrame
# Columns: [name]
# Index: []
